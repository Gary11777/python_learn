# %%
file_path = "txt/example2.txt";
mode = "w";

# %%
with open(file_path, mode) as file1:
    file1.write("This is line A\n")
    file1.write("This is line B\n");

# %%
lines = ["This is line 1", "This is line 2", "This is line 3"];

# %%
file_path3 = "txt/example3.txt";

# %%
with open(file_path3, mode) as file2:
    for line in lines:
        file2.write(line + "\n");

# %%
new_data = "This is line C";
mode_a = "a";

# %%
with open(file_path, mode_a) as file1:
    file1.write(new_data +  "\n");

# %%
with open(file_path, "r") as source_file:
    with open("txt/example4.txt","w") as destination_file: 
        for line in source_file:
            destination_file.write(line);
