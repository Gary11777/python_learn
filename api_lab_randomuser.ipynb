# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (pyproject.toml): started
#   Building wheel for randomuser (pyproject.toml): finished with status 'done'
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5128 sha256=c00c1a4947f4643bba236fbe3e78dde183d3c853e21f7a76c3a4c30d81f00a33
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\a8\ce\f1\713605b6f257e4f0efca0fe272df8e2427bd335cf907ab0dff
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x187cbc00190>,
#  <randomuser.RandomUser at 0x187cbc00050>,
#  <randomuser.RandomUser at 0x187ebbf03e0>,
#  <randomuser.RandomUser at 0x187ebbf0510>,
#  <randomuser.RandomUser at 0x187ebb91fd0>,
#  <randomuser.RandomUser at 0x187cbba2470>,
#  <randomuser.RandomUser at 0x187cbba1e10>,
#  <randomuser.RandomUser at 0x187ebb9a350>,
#  <randomuser.RandomUser at 0x187ebb9a450>,
#  <randomuser.RandomUser at 0x187eaa0b200>]

# %%
name = r.get_full_name()

# %%
for user in some_list:
    print(user.get_full_name()," ",user.get_email());
# Out:
# Dale Morris   dale.morris@example.com
# Belarmino Castro   belarmino.castro@example.com
# Owen Andersen   owen.andersen@example.com
# Milla Kalas   milla.kalas@example.com
# Kamilla Lystad   kamilla.lystad@example.com
# Walter Fleury   walter.fleury@example.com
# James Morris   james.morris@example.com
# Roy Bates   roy.bates@example.com
# Faith Carlson   faith.carlson@example.com
# Samantha Cox   samantha.cox@example.com

# %%
for user in some_list:
    print(user.get_picture()," ",user.get_full_name());
# Out:
# https://randomuser.me/api/portraits/men/72.jpg   Dale Morris
# https://randomuser.me/api/portraits/men/33.jpg   Belarmino Castro
# https://randomuser.me/api/portraits/men/80.jpg   Owen Andersen
# https://randomuser.me/api/portraits/women/60.jpg   Milla Kalas
# https://randomuser.me/api/portraits/women/41.jpg   Kamilla Lystad
# https://randomuser.me/api/portraits/men/21.jpg   Walter Fleury
# https://randomuser.me/api/portraits/men/5.jpg   James Morris
# https://randomuser.me/api/portraits/men/14.jpg   Roy Bates
# https://randomuser.me/api/portraits/women/44.jpg   Faith Carlson
# https://randomuser.me/api/portraits/women/13.jpg   Samantha Cox

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                 Name  Gender        City            State  \
# 0     Nádege Cardoso    male    Botucatu   Rio de Janeiro
# 1     Antoine Girard    male   Reisiswil              Zug
# 2         Ilyas Dinh    male      Disenå         Telemark
# 3  Carl Christiansen    male    Ryslinge       Syddanmark
# 4      Elsa Hiltunen  female      Nivala            Åland
# 5       Jason Wilson    male       Navan          Donegal
# 6     Madison Thomas  female  Wellington       Wellington
# 7     Emily Crawford  female   Toowoomba  South Australia
# 8      Margot Dupont  female    Mulhouse          Gironde
# 9        Lucas Watts    male     Memphis          Montana
#
#                            Email                       DOB  \
# 0     nadege.cardoso@example.com  1959-10-26T16:40:10.573Z
# 1     antoine.girard@example.com  1949-04-18T22:37:24.618Z
# 2         ilyas.dinh@example.com  1949-06-19T02:57:53.314Z
# 3  carl.christiansen@example.com  1985-06-16T12:13:28.450Z
# 4      elsa.hiltunen@example.com  1972-08-06T23:37:13.161Z
# 5       jason.wilson@example.com  1978-12-29T18:26:20.184Z
# 6     madison.thomas@example.com  1977-05-14T12:26:48.303Z
# 7     emily.crawford@example.com  1968-05-08T04:51:12.387Z
# 8      margot.dupont@example.com  1945-07-06T15:33:28.743Z
# 9        lucas.watts@example.com  1954-08-27T22:29:36.498Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/15.jpg
# 1    https://randomuser.me/api/portraits/men/67.jpg
# 2    https://randomuser.me/api/portraits/men/80.jpg
# 3    https://randomuser.me/api/portraits/men/58.jpg
# 4  https://randomuser.me/api/portraits/women/53.jpg
# 5    https://randomuser.me/api/portraits/men/44.jpg
# 6  https://randomuser.me/api/portraits/women/77.jpg
# 7  https://randomuser.me/api/portraits/women/96.jpg
# 8  https://randomuser.me/api/portraits/women/40.jpg
# 9    https://randomuser.me/api/portraits/men/14.jpg

# %%
df1 = pd.DataFrame(get_users())
