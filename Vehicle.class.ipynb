# %%
class Vehicle:
    
    def __init__(self, speed, mileage, color='white'):
        self.speed = speed
        self.mileage = mileage
        self.color = color;

    def setSeatingCapacity(self, seating_capacity):
        self.seating_capacity = seating_capacity;

    def getProperties(self):
        print("Speed: ",self.speed)
        print("Mileage: ",self.mileage)
        print("Color: ",self.color)
        print("Seating Capacity: ",self.seating_capacity);

# %%
Car1 = Vehicle(200, 20, 'blue');
Car1.setSeatingCapacity(5);
Car2 = Vehicle(180, 25);
Car2.setSeatingCapacity(4);

# %%
Car1.getProperties()
# Out:
# Speed:  200
# Mileage:  20
# Color:  blue
# Seating Capacity:  5

# %%
Car2.getProperties()
# Out:
# Speed:  180
# Mileage:  25
# Color:  white
# Seating Capacity:  4
