# %%
one = 1
two = 2
print(one + two)
# Out:
# 3

# %% [markdown]
# ## Create a line plot
# This tutorial shows how to create a line plot

# %%
a = [1, 2, 3, 4]
b = [-1, -2, -3, -4]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a,b)
plt.show()
